# %%
import json
import nltk
import pandas as pd
import re
from keras.preprocessing.text import Tokenizer
from keras.preprocessing.sequence import pad_sequences
from sklearn.model_selection import train_test_split
from keras.models import Sequential
from keras.layers import Dense, LSTM, Bidirectional, Dropout
from keras.layers import Flatten
from keras.layers.embeddings import Embedding
from keras.callbacks import ModelCheckpoint, EarlyStopping
import matplotlib.pyplot as plt
import numpy as np
from gensim.models import KeyedVectors
import os
from nltk.tokenize import word_tokenize

from src.core import file_manager as fm
# Out:
# 2022-06-23 15:49:01.719528: W tensorflow/stream_executor/platform/default/dso_loader.cc:64] Could not load dynamic library 'libcudart.so.11.0'; dlerror: libcudart.so.11.0: cannot open shared object file: No such file or directory
# 2022-06-23 15:49:01.719544: I tensorflow/stream_executor/cuda/cudart_stub.cc:29] Ignore above cudart dlerror if you do not have a GPU set up on your machine.

# %% [markdown]
# ## Sentences

# %%
df = fm.read_annotated_df_with_embeddings('bert_pt')

count_before = df.txt.count()

# %%
df = df.loc[df.apply(lambda x: (len(x['tokens']) == len(x['word_embeddings'])) , axis=1)]

rows_delted = count_before - df.txt.count()

print(f'There was deleted {rows_delted} rows with bad representation')
# Out:
# There was deleted 21 rows with bad representation

# %%
vocab = {}

for index, row in df.iterrows():
  for index, token in enumerate(row['tokens']):
    if token not in vocab:
      vocab[token] = np.array(row['word_embeddings'][index])

n_source_words = len(vocab)

print(n_source_words)
# Out:
# 6231

# %%
keys_lower = {}

for key in vocab.keys():
  if not key.lower() in keys_lower:
    keys_lower[key.lower()] = []

  keys_lower[key.lower()].append(key)


keys_lower
# Out:
# {'tô': ['Tô', 'tô'],
#  'muito': ['muito', 'Muito', 'MUITO'],
#  'nervosa': ['nervosa'],
#  'marcela': ['Marcela'],
#  'com': ['com', 'Com', 'COM'],
#  'tudo': ['tudo', 'Tudo'],
#  'isso': ['isso', 'Isso', 'ISSO'],
#  'medo': ['medo', 'Medo', 'MEDO'],
#  'não': ['Não', 'não', 'NÃO'],
#  'tem': ['Tem', 'tem', 'TEM'],
#  'algum': ['algum', 'Algum'],
#  'remédio': ['remédio', 'Remédio'],
#  'que': ['que', 'Que'],
#  'a': ['a', 'A'],
#  'pessoa': ['pessoa'],
#  'tome': ['tome'],
#  'para': ['para', 'Para'],
#  'se': ['se', 'Se', 'SE'],
#  'acalmar': ['acalmar'],
#  'tá': ['Tá', 'tá'],
#  'certo': ['certo', 'Certo'],
#  'bom': ['bom', 'Bom'],
#  'obrigada': ['Obrigada', 'obrigada', 'OBRIGADA'],
#  ',': [','],
#  'deus': ['Deus', 'deus', 'DEUS'],
#  'te': ['te', 'Te'],
#  'abençoe': ['abençoe'],
#  'eu': ['Eu', 'eu', 'EU'],
#  'preciso': ['preciso', 'Preciso'],
#  'de': ['de', 'De', 'DE'],
#  'um': ['um', 'Um', 'UM'],
#  'psicólogo': ['psicólogo'],
#  'pra': ['pra', 'Pra'],
#  'eles': ['eles', 'Eles'],
#  'o': ['O', 'o'],
#  'luto': ['luto'],
#  'é': ['é', 'É'],
#  'patológico': ['patológico'],
#  'e': ['e', 'E'],
#  'temor': ['temor'],
#  'do': ['do', 'DO'],
#  'corona': ['Corona', 'corona'],
#  'está': ['está', 'Está'],
#  'acabando': ['acabando'],
#  'nossa': ['Nossa', 'nossa'],
#  'família': ['família', 'FAMÍLIA'],
#  'toda': ['toda', 'Toda'],
#  'assim': ['assim', 'Assim'],
#  '!': ['!'],
#  'boa': ['Boa', 'boa'],
#  'tarde': ['tarde', 'Tarde'],
#  'estou': ['Estou', 'estou', 'ESTOU'],
#  '03': ['03'],
#  'dias': ['dias', 'DIAS', 'Dias'],
#  'febre': ['febre', 'Febre', 'FEBRE'],
#  'tosse': ['tosse', 'Tosse', 'TOSSE'],
#  'seca': ['seca', 'Seca', 'SECA'],
#  'muitas': ['muitas', 'Muitas'],
#  'dores': ['dores', 'Dores'],
#  'nas': ['nas'],
#  'costas': ['costas'],
#  'durante': ['Durante', 'durante'],
#  'esse': ['esse', 'Esse'],
#  'período': ['período'],
#  'tomei': ['tomei', 'Tomei', 'TOMEI'],
#  'dipirona': ['Dipirona', 'dipirona', 'DIPIRONA'],
#  'monoidratada': ['monoidratada'],
#  'porém': ['porém', 'Porém'],
#  'vai': ['vai', 'Vai'],
#  'volta': ['volta'],
#  '.': ['.'],
#  'pouco': ['pouco', 'Pouco', 'POUCO'],
#  'acho': ['acho', 'Acho'],
#  'por': ['por', 'Por', 'POR'],
#  'conta': ['conta'],
#  'da': ['da', 'Da', 'DA'],
#  'controlada': ['controlada'],
#  '1g': ['1g', '1G'],
#  'foi': ['foi', 'Foi'],
#  'feito': ['feito'],
#  'nenhum': ['nenhum', 'NENHUM', 'Nenhum'],
#  'exame': ['exame', 'EXAME'],
#  'médico': ['médico', 'Médico'],
#  'passou': ['passou', 'Passou'],
#  'alexofedrin': ['Alexofedrin'],
#  'd': ['D', 'd'],
#  'corisa': ['Corisa', 'corisa'],
#  'espirros': ['espirros', 'Espirros'],
#  'sekí': ['Sekí'],
#  'xarope': ['xarope'],
#  'pediu': ['Pediu', 'pediu'],
#  'me': ['me', 'Me', 'ME'],
#  'manter': ['manter'],
#  'em': ['em', 'Em', 'EM'],
#  'casa': ['casa'],
#  'minha': ['Minha', 'minha', 'MINHA'],
#  'preocupação': ['preocupação'],
#  'ter': ['ter', 'Ter'],
#  'uma': ['uma', 'Uma'],
#  'pneumonia': ['pneumonia'],
#  'silenciosa': ['silenciosa'],
#  'tou': ['Tou', 'tou'],
#  'tomando': ['tomando', 'Tomando', 'TOMANDO'],
#  'pros': ['pros'],
#  'suspender': ['suspender'],
#  '?': ['?'],
#  'desde': ['Desde', 'desde', 'DESDE'],
#  'ontem': ['ontem', 'Ontem'],
#  'sinto': ['sinto', 'Sinto', 'SINTO'],
#  'mais': ['mais', 'Mais', 'MAIS'],
#  'ruim': ['ruim'],
#  'falta': ['Falta', 'falta', 'FALTA'],
#  'ar': ['ar', 'AR', 'Ar'],
#  'à': ['à'],
#  'noite': ['noite', 'Noite'],
#  'fico': ['fico', 'Fico'],
#  'febril': ['febril', 'Febril', 'FEBRIL'],
#  'conseguindo': ['conseguindo'],
#  'controlar': ['controlar'],
#  'dia': ['dia', 'Dia', 'DIA'],
#  'temperatura': ['temperatura'],
#  'normal': ['normal'],
#  'obrigado': ['Obrigado', 'obrigado'],
#  'alguns': ['alguns', 'Alguns'],
#  'sintomas': ['sintomas', 'Sintomas', 'SINTOMAS'],
#  'segunda': ['segunda', 'Segunda'],
#  'queria': ['queria', 'Queria'],
#  'saber': ['saber'],
#  'são': ['são', 'São'],
#  'covid': ['covid', 'Covid', 'COVID', 'COViD'],
#  'dor': ['Dor', 'dor'],
#  'no': ['no', 'No', 'NO'],
#  'corpo': ['corpo', 'Corpo'],
#  'nos': ['nos', 'Nos'],
#  'olhos': ['olhos', 'Olhos'],
#  'sensação': ['sensação', 'Sensação'],
#  'bem': ['bem', 'Bem'],
#  'esporádicos': ['esporádicos'],
#  'cansaço': ['cansaço', 'Cansaço'],
#  'hoje': ['Hoje', 'hoje', 'HOJE'],
#  'manhã': ['manhã'],
#  'senti': ['senti', 'Senti'],
#  'das': ['das'],
#  'narinas': ['narinas', 'Narinas'],
#  'entupidas': ['entupidas'],
#  'tenho': ['Tenho', 'tenho', 'TENHO'],
#  'rinite': ['rinite', 'Rinite'],
#  'sinusite': ['sinusite', 'Sinusite'],
#  'to': ['to', 'To'],
#  'mas': ['Mas', 'mas', 'MAS'],
#  'termômetro': ['termômetro'],
#  'tylenol': ['Tylenol', 'tylenol'],
#  'só': ['só', 'Só', 'SÓ'],
#  'antialérgico': ['antialérgico'],
#  'alektos': ['Alektos'],
#  'já': ['Já', 'já'],
#  'vinha': ['vinha', 'Vinha'],
#  'tomado': ['tomado'],
#  'ele': ['ele', 'Ele'],
#  'antes': ['antes', 'Antes'],
#  'isolamento': ['isolamento', 'Isolamento', 'ISOLAMENTO'],
#  'na': ['na', 'Na', 'NA'],
#  'nuca': ['nuca'],
#  'acentuada': ['acentuada'],
#  'pigarro': ['pigarro'],
#  'garganta': ['garganta', 'Garganta'],
#  'tossi': ['tossi'],
#  'aula': ['aula'],
#  'leve': ['leve', 'Leve'],
#  'sim': ['Sim', 'sim', 'SIM'],
#  'como': ['Como', 'como', 'COMO'],
#  'alergia': ['alergia'],
#  'coisas': ['coisas'],
#  'penso': ['penso', 'Penso'],
#  'pode': ['pode', 'Pode', 'PODE'],
#  'ser': ['ser', 'SER'],
#  'crise': ['crise', 'Crise'],
#  'alérgica': ['alérgica', 'Alérgica'],
#  'quais': ['Quais', 'quais'],
#  'posso': ['posso', 'Posso', 'POSSO'],
#  'tomar': ['tomar', 'Tomar'],
#  'melhorar': ['melhorar'],
#  'obstrução': ['obstrução'],
#  'nasal': ['nasal'],
#  'ou': ['ou', 'Ou', 'OU'],
#  'paracetamol': ['paracetamol', 'Paracetamol'],
#  'tava': ['Tava', 'tava'],
#  'usando': ['usando'],
#  'nasonex': ['Nasonex'],
#  'alergologista': ['alergologista'],
#  'disse': ['disse', 'DISSE'],
#  'parasse': ['parasse'],
#  'tomasse': ['tomasse'],
#  'retomar': ['retomar'],
#  'uso': ['uso', 'Uso'],
#  'quando': ['quando', 'Quando'],
#  'soro': ['soro'],
#  'mesmo': ['mesmo', 'Mesmo'],
#  'ok': ['Ok', 'ok', 'OK'],
#  'sei': ['sei', 'Sei'],
#  'pressa': ['pressa'],
#  'dá': ['dá', 'Dá'],
#  'costela': ['costela'],
#  'dificuldade': ['Dificuldade', 'dificuldade'],
#  'respiração': ['respiração', 'Respiração'],
#  'apetite': ['apetite', 'APETITE'],
#  'náuseas': ['Náuseas', 'náuseas'],
#  'congestão': ['Congestão', 'congestão'],
#  'nariz': ['nariz', 'Nariz', 'NARIZ'],
#  'entupido': ['entupido', 'ENTUPIDO'],
#  'entalo': ['Entalo', 'entalo'],
#  'estomago': ['estomago'],
#  'ola': ['Ola'],
#  'os': ['Os', 'os', 'OS'],
#  'venho': ['venho', 'Venho'],
#  'sentido': ['sentido'],
#  'hj': ['hj', 'Hj', 'HJ'],
#  'cabeca': ['cabeca'],
#  'sentindo': ['sentindo', 'Sentindo'],
#  'barriga': ['barriga', 'Barriga'],
#  'vem': ['vem', 'Vem'],
#  'dando': ['dando'],
#  'barrigas': ['barrigas'],
#  'gripe': ['gripe', 'Gripe'],
#  'fzr': ['fzr'],
#  'duas': ['duas', 'Duas'],
#  'semanas': ['semanas'],
#  'início': ['início'],
#  'deu': ['deu', 'Deu'],
#  'nem': ['nem', 'Nem'],
#  'dar': ['dar'],
#  'cabeça': ['cabeça', 'Cabeça'],
#  'comecei': ['comecei', 'Comecei', 'COMECEI'],
#  'dra': ['Dra', 'dra'],
#  'detalhe': ['Detalhe', 'detalhe'],
#  'sem': ['sem', 'Sem'],
#  'olfato': ['olfato', 'Olfato'],
#  'paladar': ['paladar', 'Paladar'],
#  'repouso': ['Repouso', 'repouso'],
#  'coração': ['coração', 'Coração'],
#  'acelerado': ['acelerado'],
#  'nao': ['Nao', 'nao', 'NAO'],
#  '??': ['??'],
#  'faço': ['faço', 'Faço'],
#  'ta': ['Ta', 'ta'],
#  'nunca': ['Nunca', 'nunca'],
#  'fiquei': ['fiquei', 'Fiquei'],
#  'vez': ['vez', 'Vez'],
#  'até': ['até', 'Até'],
#  'pressao': ['pressao'],
#  'subiu': ['subiu'],
#  'fiz': ['fiz', 'Fiz', 'FIZ'],
#  'nada': ['nada', 'Nada'],
#  'medicação': ['medicação'],
#  'alguma': ['alguma', 'Alguma'],
#  'sou': ['sou', 'Sou', 'SOU'],
#  'ainda': ['Ainda', 'ainda', 'AINDA'],
#  'taquicardia': ['taquicardia', 'Taquicardia'],
#  'grande': ['grande'],
#  'q': ['q', 'Q'],
#  'normalmente': ['normalmente', 'Normalmente'],
#  '"': ['"'],
#  'certeza': ['certeza'],
#  'estive': ['estive', 'Estive'],
#  'realmente': ['realmente', 'Realmente'],
#  'contato': ['contato'],
#  'pessoas': ['pessoas'],
#  'infectadas': ['infectadas'],
#  'veio': ['veio'],
#  'amiga': ['amiga'],
#  'ela': ['ela', 'Ela'],
#  'relatou': ['relatou'],
#  'irmão': ['irmão'],
#  'dela': ['dela', 'Dela'],
#  '(': ['('],
#  '21': ['21'],
#  'anos': ['anos'],
#  ')': [')'],
#  'pai': ['pai'],
#  'acima': ['acima'],
#  '30': ['30'],
#  '),': ['),'],
#  'estavam': ['estavam'],
#  'exatas': ['exatas'],
#  'direto': ['direto'],
#  'essa': ['essa', 'Essa'],
#  'apresentou': ['apresentou', 'Apresentou'],
#  'pelo': ['pelo', 'Pelo'],
#  'menos': ['menos'],
#  'será': ['Será', 'será'],
#  'tenha': ['tenha', 'Tenha', 'TENHA'],
#  '""': ['""'],
#  'entrado': ['entrado'],
#  'deveria': ['deveria'],
#  'fazer': ['fazer', 'Fazer', 'FAZER'],
#  'teste': ['teste', 'Teste', 'TESTE'],
#  '?!"': ['?!"'],
#  'também': ['também', 'Também'],
#  'influencia': ['influencia'],
#  'imune': ['imune'],
#  'aos': ['aos', 'Aos'],
#  '19': ['19'],
#  'dentro': ['dentro'],
#  'dessa': ['dessa'],
#  'situação': ['situação'],
#  'contraído': ['contraído'],
#  'vírus': ['vírus'],
#  'tenham': ['tenham', 'Tenham'],
#  'pegado': ['pegado'],
#  'virose': ['virose'],
#  'hipótese': ['hipótese'],
#  'momento': ['momento', 'Momento', 'MOMENTO'],
#  '2': ['2'],
#  'atrás': ['atrás'],
#  'então': ['então', 'Então'],
#  'melhor': ['melhor', 'Melhor'],
#  'esperar': ['esperar'],
#  'ver': ['ver'],
#  'aparece': ['aparece'],
#  'sintoma': ['sintoma', 'SINTOMA'],
#  'correto': ['correto'],
#  'gostaria': ['Gostaria', 'gostaria', 'GOSTARIA'],
#  'qual': ['qual', 'Qual', 'QUAL'],
#  'esses': ['esses', 'Esses'],
#  'necessário': ['necessário'],
#  'ir': ['ir', 'Ir', 'IR'],
#  'unidade': ['unidade'],
#  'pior': ['pior'],
#  'arritmia': ['Arritmia', 'arritmia'],
#  'aliviar': ['aliviar'],
#  'indicar': ['indicar'],
#  'estamos': ['estamos', 'Estamos'],
#  'espirrando': ['espirrando', 'Espirrando'],
#  'depois': ['Depois', 'depois'],
#  'apareceu': ['apareceu', 'Apareceu'],
#  'coceira': ['coceira'],
#  'cheiro': ['cheiro'],
#  'sabor': ['sabor'],
#  'filha': ['filha'],
#  'síndrome': ['síndrome', 'Síndrome'],
#  'donw': ['donw'],
#  'ja': ['ja', 'Ja'],
#  'fez': ['fez', 'Fez'],
#  'cirurgia': ['cirurgia'],
#  'pois': ['Pois', 'pois'],
#  'dele': ['dele'],
#  'alto': ['alto'],
#  'mal': ['mal', 'Mal'],
#  'estar': ['estar', 'Estar'],
#  'há': ['Há', 'há'],
#  'sentiu': ['sentiu', 'Sentiu'],
#  'tomou': ['tomou', 'Tomou'],
#  'dorflex': ['dorflex', 'Dorflex'],
#  'dr': ['Dr', 'dr'],
#  'orientar': ['orientar'],
#  'amanhecer': ['amanhecer'],
#  'c': ['c', 'C'],
#  'batimentos': ['batimentos'],
#  'resultado': ['resultado'],
#  'trabalhando': ['trabalhando'],
#  'portadora': ['portadora'],
#  'lúpus': ['lúpus'],
#  '8': ['8'],
#  'gripei': ['gripei'],
#  'parte': ['parte'],
#  'trás': ['trás'],
#  'próximo': ['próximo'],
#  'mole': ['mole'],
#  'moleza': ['moleza', 'Moleza'],
#  'preocupada': ['preocupada'],
#  'pego': ['pego'],
#  'possa': ['possa', 'Possa'],
#  'tratar': ['tratar'],
#  'devo': ['devo', 'Devo', 'DEVO'],
#  'ao': ['ao', 'Ao', 'AO'],
#  'devido': ['devido', 'Devido'],
#  'constante': ['constante'],
#  'tive': ['tive', 'Tive'],
#  'algo': ['algo', 'Algo'],
#  'estranho': ['estranho'],
#  'meu': ['meu', 'Meu', 'MEU'],
#  'explicar': ['explicar'],
#  'muitoo': ['Muitoo', 'muitoo'],
#  'quarta': ['quarta', 'Quarta'],
#  'vou': ['vou', 'Vou'],
#  'hospital': ['hospital', 'HOSPITAL', 'Hospital'],
#  'clínicas': ['clínicas'],
#  'onde': ['onde', 'Onde'],
#  'acompanhada': ['acompanhada'],
#  'deixaram': ['deixaram'],
#  'ciente': ['ciente'],
#  'qualquer': ['qualquer', 'Qualquer'],
#  'coisa': ['coisa', 'COISA'],
#  'poderia': ['poderia', 'Poderia'],
#  'n': ['N', 'n'],
#  'acompanhamento': ['acompanhamento'],
#  'seria': ['seria', 'Seria'],
#  'junho': ['junho'],
#  'médica': ['médica'],
#  'papel': ['papel'],
#  'informações': ['informações'],
#  'sobre': ['sobre', 'Sobre'],
#  'doença': ['doença', 'Doença'],
#  'caso': ['caso', 'Caso', 'CASO'],
#  'precise': ['precise'],
#  'no.hospital': ['no.hospital'],
#  'apresentar': ['apresentar'],
#  'deixarem': ['deixarem'],
#  'entrar': ['entrar'],
#  'enquanto': ['enquanto'],
#  'moro': ['moro', 'Moro'],
#  'criancas': ['criancas'],
#  'estão': ['estão', 'Estão'],
#  'catapora': ['catapora'],
#  'obgda': ['Obgda', 'obgda'],
#  '!!!': ['!!!'],
#  'pela': ['PELA', 'pela', 'Pela'],
#  'atencai': ['ATENCAI'],
#  'irritada': ['irritada'],
#  'dúvida': ['dúvida'],
#  'era': ['era', 'Era', 'ERA'],
#  'medicamento': ['medicamento', 'Medicamento'],
#  'porque': ['Porque', 'porque'],
#  'irritação': ['irritação', 'Irritação'],
#  'passa': ['passa', 'Passa'],
#  'avermelhada': ['avermelhada'],
#  'medi': ['medi'],
#  'pq': ['pq', 'Pq'],
#  'causar': ['causar'],
#  'pânico': ['pânico', 'Pânico'],
#  'aqui': ['aqui', 'Aqui', 'AQUI'],
#  'temos': ['temos', 'Temos'],
#  'aparelho': ['aparelho'],
#  'apenas': ['apenas', 'Apenas'],
#  'meio': ['meio', 'MEIO'],
#  'tonto': ['tonto'],
#  'quente': ['quente'],
#  'amanhã': ['amanhã', 'Amanhã'],
#  'procuro': ['procuro', 'Procuro'],
#  'saúde': ['saúde', 'Saúde', 'SAÚDE'],
#  'ubs': ['UBS'],
#  'upa': ['UPA', 'upa', 'Upa'],
#  '4': ['4'],
#  'mal-estár': ['mal-estár'],
#  'doer': ['doer'],
#  'estivesse': ['estivesse'],
#  'cansada': ['cansada', 'Cansada'],
#  'sentir': ['sentir', 'Sentir'],
#  'alta': ['alta'],
#  'fraqueza': ['fraqueza', 'Fraqueza'],
#  'rodando': ['rodando'],
#  'consigo': ['consigo', 'Consigo'],
#  'ficar': ['ficar', 'Ficar'],
#  'pé': ['pé'],
#  'parece': ['parece', 'Parece'],
#  'deitada': ['deitada'],
#  'meus': ['meus', 'Meus', 'MEUS'],
#  'ficam': ['ficam'],
#  'semiabertos': ['semiabertos'],
#  'lacrimejando': ['lacrimejando'],
#  'desculpe': ['desculpe', 'Desculpe'],
#  'alimentando': ['alimentando'],
#  'tomo': ['tomo', 'Tomo', 'TOMO'],
#  'banho': ['banho'],
#  'gosto': ['gosto', 'Gosto'],
#  'difícil': ['difícil', 'Difícil'],
#  'comer': ['comer'],
#  'qdo': ['qdo', 'Qdo'],
#  'passo': ['passo', 'Passo'],
#  'tempo': ['tempo'],
#  'bebê': ['bebê'],
#  'braço': ['braço'],
#  'tira': ['tira'],
#  'apavorada': ['apavorada'],
#  'graças': ['Graças', 'graças'],
#  'obg': ['Obg', 'obg'],
#  'so': ['so', 'So', 'SO'],
#  'agora': ['agora', 'Agora'],
#  'muitíssimo': ['Muitíssimo'],
#  'coçando': ['coçando'],
#  'tossindo': ['tossindo', 'Tossindo', 'TOSSINDO'],
#  'hora': ['hora'],
#  'arranhando': ['arranhando'],
#  'ansiedades': ['ansiedades'],
#  'oq': ['Oq', 'oq'],
#  'doente': ['doente'],
#  'qndo': ['Qndo', 'qndo'],
#  'começo': ['começo', 'Começo'],
#  'pensar': ['pensar'],
#  'nessa': ['nessa', 'Nessa'],
#  'logo': ['logo', 'Logo'],
#  'cert': ['Cert', 'cert'],
#  'oi': ['oi', 'Oi'],
#  'coriza': ['coriza', 'Coriza'],
#  'peito': ['peito'],
#  'continuo': ['continuo', 'Continuo'],
#  'horas': ['horas'],
#  'posto': ['posto', 'Posto'],
#  'funciona': ['funciona', 'Funciona'],
#  'faz': ['Faz', 'faz'],
#  '3': ['3'],
#  'muita': ['muita', 'Muita', 'MUITA', 'MuitA'],
#  'congestionado': ['congestionado'],
#  'deve': ['deve', 'Deve'],
#  'procurar': ['procurar', 'Procurar'],
#  'medico': ['medico'],
#  'comprei': ['Comprei', 'comprei'],
#  'alegra': ['Alegra'],
#  'farmácia': ['farmácia', 'Farmácia'],
#  'começou': ['começou', 'Começou'],
#  'região': ['região'],
#  'respiro': ['respiro', 'Respiro'],
#  'pontada': ['pontada'],
#  'ardência': ['ardência', 'Ardência'],
#  'piora': ['Piora', 'piora'],
#  'fica': ['fica', 'Fica'],
#  'forte': ['forte', 'Forte'],
#  'devagar': ['devagar'],
#  'alteração': ['alteração'],
#  'permanecer': ['permanecer'],
#  'aí': ['aí', 'Aí'],
#  'grave': ['grave'],
#  'atendimento': ['atendimento'],
#  'aconteça': ['aconteça'],
#  'voltar': ['voltar', 'VOLTAR'],
#  'falar': ['falar'],
#  'atenção': ['atenção'],
#  'tranquila': ['tranquila'],
#  '8hrs': ['8hrs'],
#  'quero': ['Quero', 'quero'],
#  'tbm': ['tbm', 'Tbm'],
#  'dói': ['Dói', 'dói'],
#  'força': ['força'],
#  'né': ['né'],
#  'outra': ['Outra', 'outra'],
#  'vc': ['vc', 'Vc', 'VC'],
#  'problema': ['problema', 'PROBLEMA'],
#  'ansiedade': ['ansiedade', 'Ansiedade'],
#  'nervoso': ['nervoso', 'Nervoso'],
#  'ia': ['ia'],
#  'kk': ['kk'],
#  'porquê': ['porquê'],
#  'baixa': ['baixa', 'Baixa'],
#  'infecção': ['infecção'],
#  'intestinal': ['intestinal'],
#  'diarréia': ['diarréia', 'Diarréia'],
#  'peitos': ['peitos'],
#  'vontade': ['vontade'],
#  'tossir': ['tossir'],
#  'puxo': ['puxo'],
#  'inspiração': ['Inspiração'],
#  'profunda': ['profunda'],
#  'todo': ['todo', 'Todo'],
#  'madrugada': ['madrugada'],
#  'as': ['as', 'As'],
#  '10h': ['10h'],
#  'ivermectina': ['ivermectina', 'Ivermectina'],
#  'comprimidos': ['comprimidos'],
#  'azitromicina': ['azitromicina', 'Azitromicina', 'AZITROMICINA'],
#  'estranha': ['estranha'],
#  'garganta,uma': ['garganta,uma'],
#  'ar,uma': ['ar,uma'],
#  'secura': ['secura'],
#  'boca': ['boca', 'Boca'],
#  'acabei': ['Acabei', 'acabei'],
#  'aliviou': ['aliviou', 'Aliviou'],
#  'última': ['última'],
#  'crises': ['crises', 'Crises'],
#  'vezes': ['vezes'],
#  'pequena': ['pequena'],
#  'costumo': ['costumo'],
#  'sempre': ['sempre', 'Sempre'],
#  'prescrição': ['prescrição'],
#  'entendi': ['Entendi', 'entendi'],
#  'utilizei': ['utilizei'],
#  'acha': ['acha', 'Acha', 'ACHA'],
#  'incômodo': ['incômodo', 'Incômodo'],
#  'srm': ['srm'],
#  'isolar': ['isolar'],
#  'deles': ['deles'],
#  '..': ['..'],
#  'respirar': ['respirar', 'Respirar'],
#  'mae': ['mae'],
#  'teve': ['teve', 'Teve'],
#  'continuar': ['continuar', 'CONTINUAR'],
#  'pegar': ['pegar'],
#  'diária': ['diária'],
#  'preocupo': ['preocupo'],
#  'comigo': ['comigo'],
#  'morar': ['morar'],
#  'junto': ['junto', 'Junto'],
#  'toma': ['toma'],
#  'mim': ['mim', 'Mim'],
#  'ansiosa': ['ansiosa'],
#  'desconforto': ['desconforto', 'Desconforto'],
#  'tivesse': ['tivesse', 'TIVESSE'],
#  'impedindo': ['impedindo'],
#  'passagem': ['passagem'],
#  'bagunçada': ['bagunçada'],
#  'acordar': ['acordar'],
#  'cedo': ['cedo'],
#  'estudar': ['estudar'],
#  'preguiça': ['preguiça'],
#  'cuidar': ['cuidar'],
#  'ate': ['ate', 'Ate'],
#  'conseguia': ['conseguia'],
#  'cronograma': ['cronograma'],
#  'seguir': ['seguir'],
#  'cabelo': ['cabelo'],
#  'pintei': ['pintei'],
#  'ótimo': ['ótimo', 'Ótimo'],
#  'conversar': ['conversar'],
#  'alguém': ['alguém', 'Alguém'],
#  'seja': ['seja'],
#  'namorado': ['namorado'],
#  'escuta': ['escuta'],
#  'fala': ['fala'],
#  'ouvir': ['ouvir'],
#  'escutar': ['escutar'],
#  'conselhos': ['conselhos'],
#  'choro': ['choro'],
#  'pôr': ['pôr'],
#  'sentimentos': ['sentimentos'],
#  'fora': ['fora', 'Fora'],
#  'ocupada': ['ocupada'],
#  'comercio': ['comercio'],
#  'chega': ['chega'],
#  'mantemos': ['mantemos'],
#  'tinha': ['tinha', 'Tinha'],
#  'dito': ['dito'],
#  'vieram': ['Vieram', 'vieram'],
#  'você': ['Você', 'você'],
#  'precisa': ['precisa', 'Precisa', 'PRECISA'],
#  'cuido': ['Cuido', 'cuido'],
#  'mãe': ['mãe'],
#  'idosa': ['idosa'],
#  'parkson': ['parkson'],
#  'ficou': ['Ficou', 'ficou'],
#  'fosse': ['fosse', 'Fosse', 'FOSSE'],
#  'tontura': ['Tontura', 'tontura'],
#  'pré': ['pré', 'Pré'],
#  'diabética': ['diabética', 'Diabética'],
#  'idometriose': ['Idometriose'],
#  'reeducação': ['reeducação'],
#  'alimentar': ['alimentar'],
#  'amém': ['Amém'],
#  'alerfica': ['alerfica'],
#  'alivia': ['alivia'],
#  'benício': ['Benício'],
#  'razão': ['razão'],
#  'demonstrou': ['demonstrou'],
#  'efeito': ['efeito'],
#  'anteriores': ['anteriores', 'Anteriores'],
#  'home': ['home'],
#  'office': ['office'],
#  '18': ['18'],
#  'março': ['março'],
#  'saí': ['saí'],
#  'semana': ['semana', 'Semana'],
#  'mercantil': ['mercantil'],
#  'partir': ['partir'],
#  'desta': ['desta'],
#  'compras': ['compras'],
#  'aplicativo': ['aplicativo'],
#  'quarentena': ['quarentena'],
#  'saiba': ['saiba'],
#  ':)': [':)'],
#  '6': ['6'],
#  'pressão': ['pressão', 'Pressão'],
#  'ausência': ['ausência'],
#  'marido': ['marido', 'Marido'],
#  'sábado': ['sábado', 'Sábado'],
#  'quebradeira': ['quebradeira'],
#  '38.1': ['38.1'],
#  'graus': ['graus'],
#  'nimesulida': ['Nimesulida', 'nimesulida'],
#  '?!': ['?!'],
#  'pedir': ['pedir'],
#  'utilizar': ['utilizar'],
#  'somente': ['somente', 'Somente'],
#  '!!': ['!!'],
#  'fundo': ['fundo'],
#  'houvesse': ['houvesse'],
#  'restrição': ['restrição'],
#  'pulmão': ['pulmão'],
#  'diminuiu': ['diminuiu', 'Diminuiu'],
#  'procurei': ['Procurei', 'procurei'],
#  'medicamentos': ['medicamentos'],
#  'sucesso': ['sucesso'],
#  'pedra': ['pedra'],
#  'versícula': ['versícula'],
#  'dorzinha': ['dorzinha'],
#  'pelas': ['pelas'],
#  'orientações': ['orientações'],
#  'deste': ['Deste'],
#  'uns': ['uns', 'Uns'],
#  'bastante': ['bastante', 'BASTANTE', 'Bastante'],
#  '37.6': ['37.6'],
#  'amanhece': ['amanhece'],
#  'cetoprofeno': ['cetoprofeno'],
#  'versicula': ['versicula'],
#  'escura': ['escura'],
#  'fazendo': ['fazendo'],
#  'online': ['online'],
#  'vocês': ['vocês', 'Vocês'],
#  'podem': ['podem'],
#  'ajudar': ['ajudar'],
#  '55': ['55'],
#  'diabetes': ['diabetes', 'Diabetes'],
#  'hipertensão': ['hipertensão', 'Hipertensão'],
#  'insuficiência': ['insuficiência'],
#  'renal': ['renal', 'Renal'],
#  'domingo': ['domingo', 'Domingo'],
#  'principalmente': ['principalmente', 'Principalmente'],
#  'rins': ['rins'],
#  'cheguei': ['cheguei', 'Cheguei'],
#  'imaginar': ['imaginar'],
#  'esteja': ['esteja'],
#  'inflamado': ['inflamado'],
#  'xixi': ['xixi'],
#  'espumando': ['espumando'],
#  'paciente': ['paciente'],
#  'conservadora': ['conservadora'],
#  'levá-la': ['levá-la'],
#  'perigoso': ['perigoso'],
#  'número': ['número'],
#  'casos': ['casos'],
#  'confirmados': ['confirmados'],
#  'daqui': ['daqui', 'Daqui'],
#  'marcando': ['marcando'],
#  'consultas': ['consultas'],
#  'tio': ['tio'],
#  'aumenta': ['aumenta'],
#  'doída': ['doída'],
#  'leves': ['leves'],
#  'chegar': ['chegar'],
#  'lá': ['lá', 'Lá'],
#  'dizer': ['dizer', 'DIZER'],
#  'novo': ['novo'],
#  'saiu': ['saiu'],
#  'avisar': ['avisar'],
#  'remédios': ['remédios'],
#  'oseltamivir': ['Oseltamivir', 'oseltamivir'],
#  '7': ['7'],
#  'estava': ['estava', 'Estava'],
#  'continua': ['continua', 'Continua'],
#  'saberia': ['saberia'],
#  'esta': ['esta', 'Esta', 'ESTA'],
#  'funcionándo': ['funcionándo'],
#  'bon': ['bon'],
#  'melhorando': ['melhorando', 'Melhorando'],
#  'disposta': ['disposta'],
#  'termometro': ['termometro'],
#  'mto': ['mto', 'Mto'],
#  'frio': ['frio'],
#  'dolorido': ['dolorido'],
#  'refluxo': ['refluxo', 'Refluxo'],
#  'laringite': ['laringite'],
#  'fendas': ['Fendas'],
#  'cordas': ['cordas'],
#  'vocais': ['vocais'],
#  'alerguca': ['alerguca'],
#  'cim': ['cim'],
#  'agira': ['agira'],
#  'quebrado': ['quebrado'],
#  'sibdrome': ['sibdrome'],
#  'gripal': ['gripal'],
#  'rapida': ['Rapida'],
#  'esforço': ['esforço', 'Esforço'],
#  'percebi': ['percebi', 'Percebi'],
#  'salivando': ['salivando'],
#  'twm': ['twm'],
#  'relação': ['relação'],
#  'celerg': ['celerg'],
#  '500': ['500'],
#  'gracas': ['Gracas', 'gracas', 'GRACAS'],
#  'ajuda': ['ajuda'],
#  'trabalho': ['trabalho', 'Trabalho', 'TRABALHO'],
#  'melhorei': ['Melhorei', 'melhorei'],
#  'azitromucina': ['Azitromucina'],
#  'fosfato': ['Fosfato', 'fosfato'],
#  'oseltsmivir': ['oseltsmivir'],
#  '10': ['10'],
#  'meses': ['meses'],
#  '38.6': ['38.6'],
#  'dois': ['dois', 'DOIS', 'Dois'],
#  'diarreia': ['diarreia', 'Diarreia'],
#  'reclamando': ['reclamando'],
#  'tirar': ['tirar'],
#  'necessidade': ['necessidade', 'NECESSIDADE'],
#  'passei': ['Passei', 'passei'],
#  '38.7': ['38.7'],
#  'voltava': ['voltava'],
#  'como.enjoo': ['como.enjoo'],
#  'três': ['três'],
#  'primeiros': ['primeiros', 'Primeiros'],
#  'como.nariz': ['como.nariz'],
#  'escorrendo': ['escorrendo'],
#  'enjoo': ['enjoo'],
#  'remedio': ['remedio', 'REMEDIO'],
#  '5': ['5'],
#  'debaixo': ['debaixo'],
#  'lado': ['lado'],
#  'esquerdo': ['esquerdo'],
#  'disviado': ['disviado'],
#  'enquando': ['enquando'],
#  'fina': ['fina'],
#  '29,nao': ['29,nao'],
#  'morrer': ['morrer'],
#  'durmo': ['durmo'],
#  'filho': ['filho'],
#  'pesadelo': ['pesadelo'],
#  'iseletrica': ['Iseletrica'],
#  'filhos': ['filhos'],
#  'trabalham': ['trabalham'],
#  'velho': ['velho'],
#  'infelizmente': ['infelizmente', 'Infelizmente'],
#  'preso': ['preso'],
#  'colocaram': ['colocaram'],
#  'dinheiro': ['dinheiro'],
#  'policiais': ['policiais'],
#  'incriminam': ['incriminam'],
#  'aflingi': ['aflingi'],
#  'laudo': ['laudo'],
#  'aposentado': ['aposentado'],
#  'tratamento': ['tratamento', 'Tratamento'],
#  'caps,ele': ['caps,ele'],
#  'recusa': ['recusa'],
#  'beber': ['beber', 'Beber'],
#  'apavora': ['apavora'],
#  'tarefa': ['tarefa'],
#  'difícil,trabalhar': ['difícil,trabalhar'],
#  'seu': ['seu', 'Seu'],
#  'filho,preso': ['filho,preso'],
#  'correndo': ['correndo'],
#  'risco': ['risco'],
#  'poder': ['poder'],
#  'sair': ['sair'],
#  'quem': ['quem', 'Quem'],
#  'conheço': ['conheço', 'Conheço'],
#  'deixar': ['deixar'],
#  'descubram': ['descubram'],
#  'diagnóstico': ['diagnóstico'],
#  'positivo': ['positivo'],
#  'inflamada': ['inflamada'],
#  'flamador': ['flamador'],
#  'antiflamatorio': ['antiflamatorio', 'Antiflamatorio'],
#  '19:15': ['19:15'],
#  'horário': ['horário'],
#  'vir': ['vir'],
#  'moca': ['Moca', 'moca'],
#  'cuidados': ['cuidados'],
#  'alguem': ['alguem'],
#  'termmetro': ['termmetro'],
#  'cança': ['cança'],
#  'abencoe': ['abencoe'],
#  'cuide': ['cuide'],
#  'todos': ['todos', 'Todos'],
#  'nós': ['nós', 'Nós'],
#  'atencao': ['atencao'],
#  'colegas': ['colegas'],
#  'parecidos,mas': ['parecidos,mas'],
#  'soube': ['soube'],
#  'disso': ['disso'],
#  'fazem': ['fazem', 'Fazem'],
#  'canseira': ['canseira', 'Canseira'],
#  'incontrolável': ['incontrolável'],
#  'covid,mas': ['covid,mas'],
#  'atendeu': ['atendeu'],
#  'pelos': ['pelos', 'Pelos'],
#  'não.obrigada': ['Não.Obrigada'],
#  '12': ['12'],
#  'bombinha': ['bombinha', 'Bombinha'],
#  'aerolin': ['Aerolin', 'aerolin'],
#  'usei': ['usei', 'Usei'],
#  'geralmente': ['geralmente', 'Geralmente'],
#  'plano': ['plano', 'PLANO'],
#  'fui': ['fui', 'Fui', 'FUI'],
#  'contaminar': ['contaminar'],
#  'jato': ['jato'],
#  'vick': ['Vick', 'vick'],
#  'tiver': ['tiver'],
#  'disseram': ['disseram'],
#  'sinais': ['sinais', 'Sinais'],
#  'eram': ['eram'],
#  'alarmantes': ['alarmantes'],
#  'insuportável': ['insuportável'],
#  'noites': ['noites'],
#  'verdade': ['verdade'],
#  'perguntaram': ['perguntaram'],
#  'intensa': ['intensa'],
#  'asma': ['asma', 'Asma'],
#  'verifiquei': ['Verifiquei', 'verifiquei'],
#  '36,8°': ['36,8°'],
#  '36,5°': ['36,5°'],
#  'stefane': ['Stefane'],
#  'explicações': ['explicações'],
#  'válido': ['válido'],
#  'luciana': ['Luciana', 'luciana'],
#  'dei': ['Dei', 'dei'],
#  'pronto': ['Pronto'],
#  'ponto': ['ponto'],
#  'eaclarecer': ['eaclarecer'],
#  'iniciaram': ['iniciaram'],
#  'jantou': ['jantou'],
#  'comida': ['comida'],
#  'esperança': ['esperança'],
#  '30/04': ['30/04'],
#  ':': [':'],
#  'corporal': ['corporal'],
#  'variando': ['variando'],
#  'entre': ['entre', 'Entre'],
#  '01/05': ['01/05'],
#  'amanheceu': ['amanheceu'],
#  'mau': ['mau'],
#  'possibilidade': ['possibilidade'],
#  'sejam': ['sejam'],
#  'relativos': ['relativos'],
#  '3dias': ['3dias'],
#  'frebre': ['frebre', 'Frebre'],
#  'frebe': ['frebe'],
#  'doendo': ['doendo'],
#  'espirrou': ['espirrou'],
#  'crianças': ['crianças'],
#  'sugestivo': ['sugestivo'],
#  'sitomas': ['sitomas'],
#  'gastro': ['gastro'],
#  'intestinais': ['intestinais'],
#  'desculpa': ['desculpa', 'Desculpa'],
#  'amem': ['Amem'],
#  'acontece': ['acontece', 'Acontece'],
#  'raramente': ['raramente'],
#  'aparentemente': ['aparentemente', 'Aparentemente'],
#  'incomoda': ['incomoda', 'Incomoda'],
#  'ai': ['Ai', 'ai', 'AI'],
#  'dorfex': ['dorfex'],
#  'coronavirus': ['Coronavirus', 'coronavirus'],
#  'agradeço': ['agradeço', 'Agradeço'],
#  'doutora': ['Doutora', 'doutora'],
#  'fraca': ['fraca', 'Fraca'],
#  'tonta': ['tonta'],
#  'tmb': ['tmb', 'Tmb', 'TMB'],
#  'resfriada': ['resfriada'],
#  'povo': ['povo'],
#  'mascara': ['mascara'],
#  'angustiada': ['angustiada', 'Angustiada'],
#  'remdios': ['remdios'],
#  'caseiros': ['caseiros'],
#  'bebido': ['bebido'],
#  'liquido': ['liquido'],
#  'vigilancia': ['vigilancia'],
#  'sanitaria': ['sanitaria'],
#  'seguro': ['seguro'],
#  'tido': ['tido'],
#  'afetado': ['afetado'],
#  'emocional': ['emocional'],
#  'perder': ['perder'],
#  'amo': ['amo'],
#  'descontroladamente': ['descontroladamente'],
#  'estômago': ['estômago', 'Estômago'],
#  'senão': ['senão'],
#  'comido': ['comido'],
#  'médicos': ['médicos'],
#  'dores,não': ['dores,não'],
#  'mandou': ['mandou', 'Mandou'],
#  'domiciliar': ['domiciliar'],
#  'receitou': ['Receitou', 'receitou'],
#  ';': [';'],
#  'fisiológico': ['fisiológico'],
#  'loratadina': ['loratadina', 'Loratadina'],
#  'passado': ['passado'],
#  'pimenta': ['pimenta'],
#  'rosto': ['rosto', 'Rosto'],
#  'fogo': ['fogo'],
#  '38.5': ['38.5'],
#  'pouca': ['Pouca', 'pouca'],
#  'lombar': ['lombar'],
#  'dolorida': ['dolorida'],
#  'mente': ['Mente', 'mente'],
#  'costa': ['Costa', 'costa'],
#  'aimda': ['aimda'],
#  'ofegante': ['ofegante'],
#  'qd': ['qd', 'Qd'],
#  'chás': ['chás'],
#  'voltando': ['voltando'],
#  'primeiro': ['primeiro', 'Primeiro'],
#  'precisei': ['precisei', 'Precisei'],
#  'otoclinica': ['otoclinica'],
#  'articulações': ['articulações'],
#  'fraco': ['fraco'],
#  'ando': ['ando', 'Ando'],
#  'tossia': ['tossia'],
#  'brena,já': ['Brena,já'],
#  'gripado': ['gripado'],
#  '1': ['1'],
#  'pesada': ['pesada'],
#  'pesso': ['pesso'],
#  'diariamente': ['diariamente'],
#  'redoxon': ['redoxon', 'Redoxon'],
#  'breve': ['breve'],
#  ...}

# %%
vocab['bom'][:10]
# Out:
# array([-0.15446484, -0.59753007, -0.12694153,  0.31093362,  0.44728976,
#         0.1666815 , -0.05694415, -0.01199269,  0.24765942, -0.6515901 ])

# %%
keys_with_variations ={key: value for key, value in keys_lower.items() if len(value) > 1}

for key in keys_with_variations.keys():
  first_key = keys_with_variations[key][0]
  
  for index in range(1, len(keys_with_variations[key])):
    key_to_compare = keys_with_variations[key][index]
    
    if not (vocab[first_key] == vocab[key_to_compare]).all():
      print(f'There is a diference between: {first_key} and {key_to_compare} ')
# Out:
# There is a diference between: Tô and tô
# There is a diference between: muito and Muito
# There is a diference between: muito and MUITO
# There is a diference between: com and Com
# There is a diference between: com and COM
# There is a diference between: tudo and Tudo
# There is a diference between: isso and Isso
# There is a diference between: isso and ISSO
# There is a diference between: medo and Medo
# There is a diference between: medo and MEDO
# There is a diference between: Não and não
# There is a diference between: Não and NÃO
# There is a diference between: Tem and tem
# There is a diference between: Tem and TEM
# There is a diference between: algum and Algum
# There is a diference between: remédio and Remédio
# There is a diference between: que and Que
# There is a diference between: a and A
# There is a diference between: para and Para
# There is a diference between: se and Se
# There is a diference between: se and SE
# There is a diference between: Tá and tá
# There is a diference between: certo and Certo
# There is a diference between: bom and Bom
# There is a diference between: Obrigada and obrigada
# There is a diference between: Obrigada and OBRIGADA
# There is a diference between: Deus and deus
# There is a diference between: Deus and DEUS
# There is a diference between: te and Te
# There is a diference between: Eu and eu
# There is a diference between: Eu and EU
# There is a diference between: preciso and Preciso
# There is a diference between: de and De
# There is a diference between: de and DE
# There is a diference between: um and Um
# There is a diference between: um and UM
# There is a diference between: pra and Pra
# There is a diference between: eles and Eles
# There is a diference between: O and o
# There is a diference between: é and É
# There is a diference between: e and E
# There is a diference between: do and DO
# There is a diference between: Corona and corona
# There is a diference between: está and Está
# There is a diference between: Nossa and nossa
# There is a diference between: família and FAMÍLIA
# There is a diference between: toda and Toda
# There is a diference between: assim and Assim
# There is a diference between: Boa and boa
# There is a diference between: tarde and Tarde
# There is a diference between: Estou and estou
# There is a diference between: Estou and ESTOU
# There is a diference between: dias and DIAS
# There is a diference between: dias and Dias
# There is a diference between: febre and Febre
# There is a diference between: febre and FEBRE
# There is a diference between: tosse and Tosse
# There is a diference between: tosse and TOSSE
# There is a diference between: seca and Seca
# There is a diference between: seca and SECA
# There is a diference between: muitas and Muitas
# There is a diference between: dores and Dores
# There is a diference between: Durante and durante
# There is a diference between: esse and Esse
# There is a diference between: tomei and Tomei
# There is a diference between: tomei and TOMEI
# There is a diference between: Dipirona and dipirona
# There is a diference between: Dipirona and DIPIRONA
# There is a diference between: porém and Porém
# There is a diference between: vai and Vai
# There is a diference between: pouco and Pouco
# There is a diference between: pouco and POUCO
# There is a diference between: acho and Acho
# There is a diference between: por and Por
# There is a diference between: por and POR
# There is a diference between: da and Da
# There is a diference between: da and DA
# There is a diference between: 1g and 1G
# There is a diference between: foi and Foi
# There is a diference between: nenhum and NENHUM
# There is a diference between: nenhum and Nenhum
# There is a diference between: exame and EXAME
# There is a diference between: médico and Médico
# There is a diference between: passou and Passou
# There is a diference between: D and d
# There is a diference between: Corisa and corisa
# There is a diference between: espirros and Espirros
# There is a diference between: Pediu and pediu
# There is a diference between: me and Me
# There is a diference between: me and ME
# There is a diference between: em and Em
# There is a diference between: em and EM
# There is a diference between: Minha and minha
# There is a diference between: Minha and MINHA
# There is a diference between: ter and Ter
# There is a diference between: uma and Uma
# There is a diference between: Tou and tou
# There is a diference between: tomando and Tomando
# There is a diference between: tomando and TOMANDO
# There is a diference between: Desde and desde
# There is a diference between: Desde and DESDE
# There is a diference between: ontem and Ontem
# There is a diference between: sinto and Sinto
# There is a diference between: sinto and SINTO
# There is a diference between: mais and Mais
# There is a diference between: mais and MAIS
# There is a diference between: Falta and falta
# There is a diference between: Falta and FALTA
# There is a diference between: ar and AR
# There is a diference between: ar and Ar
# There is a diference between: noite and Noite
# There is a diference between: fico and Fico
# There is a diference between: febril and Febril
# There is a diference between: febril and FEBRIL
# There is a diference between: dia and Dia
# There is a diference between: dia and DIA
# There is a diference between: Obrigado and obrigado
# There is a diference between: alguns and Alguns
# There is a diference between: sintomas and Sintomas
# There is a diference between: sintomas and SINTOMAS
# There is a diference between: segunda and Segunda
# There is a diference between: queria and Queria
# There is a diference between: são and São
# There is a diference between: covid and Covid
# There is a diference between: covid and COVID
# There is a diference between: covid and COViD
# There is a diference between: Dor and dor
# There is a diference between: no and No
# There is a diference between: no and NO
# There is a diference between: corpo and Corpo
# There is a diference between: nos and Nos
# There is a diference between: olhos and Olhos
# There is a diference between: sensação and Sensação
# There is a diference between: bem and Bem
# There is a diference between: cansaço and Cansaço
# There is a diference between: Hoje and hoje
# There is a diference between: Hoje and HOJE
# There is a diference between: senti and Senti
# There is a diference between: narinas and Narinas
# There is a diference between: Tenho and tenho
# There is a diference between: Tenho and TENHO
# There is a diference between: rinite and Rinite
# There is a diference between: sinusite and Sinusite
# There is a diference between: to and To
# There is a diference between: Mas and mas
# There is a diference between: Mas and MAS
# There is a diference between: Tylenol and tylenol
# There is a diference between: só and Só
# There is a diference between: só and SÓ
# There is a diference between: Já and já
# There is a diference between: vinha and Vinha
# There is a diference between: ele and Ele
# There is a diference between: antes and Antes
# There is a diference between: isolamento and Isolamento
# There is a diference between: isolamento and ISOLAMENTO
# There is a diference between: na and Na
# There is a diference between: na and NA
# There is a diference between: garganta and Garganta
# There is a diference between: leve and Leve
# There is a diference between: Sim and sim
# There is a diference between: Sim and SIM
# There is a diference between: Como and como
# There is a diference between: Como and COMO
# There is a diference between: penso and Penso
# There is a diference between: pode and Pode
# There is a diference between: pode and PODE
# There is a diference between: ser and SER
# There is a diference between: crise and Crise
# There is a diference between: alérgica and Alérgica
# There is a diference between: Quais and quais
# There is a diference between: posso and Posso
# There is a diference between: posso and POSSO
# There is a diference between: tomar and Tomar
# There is a diference between: ou and Ou
# There is a diference between: ou and OU
# There is a diference between: paracetamol and Paracetamol
# There is a diference between: Tava and tava
# There is a diference between: disse and DISSE
# There is a diference between: uso and Uso
# There is a diference between: quando and Quando
# There is a diference between: mesmo and Mesmo
# There is a diference between: Ok and ok
# There is a diference between: Ok and OK
# There is a diference between: sei and Sei
# There is a diference between: dá and Dá
# There is a diference between: Dificuldade and dificuldade
# There is a diference between: respiração and Respiração
# There is a diference between: apetite and APETITE
# There is a diference between: Náuseas and náuseas
# There is a diference between: Congestão and congestão
# There is a diference between: nariz and Nariz
# There is a diference between: nariz and NARIZ
# There is a diference between: entupido and ENTUPIDO
# There is a diference between: Entalo and entalo
# There is a diference between: Os and os
# There is a diference between: Os and OS
# There is a diference between: venho and Venho
# There is a diference between: hj and Hj
# There is a diference between: hj and HJ
# There is a diference between: sentindo and Sentindo
# There is a diference between: barriga and Barriga
# There is a diference between: vem and Vem
# There is a diference between: gripe and Gripe
# There is a diference between: duas and Duas
# There is a diference between: deu and Deu
# There is a diference between: nem and Nem
# There is a diference between: cabeça and Cabeça
# There is a diference between: comecei and Comecei
# There is a diference between: comecei and COMECEI
# There is a diference between: Dra and dra
# There is a diference between: Detalhe and detalhe
# There is a diference between: sem and Sem
# There is a diference between: olfato and Olfato
# There is a diference between: paladar and Paladar
# There is a diference between: Repouso and repouso
# There is a diference between: coração and Coração
# There is a diference between: Nao and nao
# There is a diference between: Nao and NAO
# There is a diference between: faço and Faço
# There is a diference between: Ta and ta
# There is a diference between: Nunca and nunca
# There is a diference between: fiquei and Fiquei
# There is a diference between: vez and Vez
# There is a diference between: até and Até
# There is a diference between: fiz and Fiz
# There is a diference between: fiz and FIZ
# There is a diference between: nada and Nada
# There is a diference between: alguma and Alguma
# There is a diference between: sou and Sou
# There is a diference between: sou and SOU
# There is a diference between: Ainda and ainda
# There is a diference between: Ainda and AINDA
# There is a diference between: taquicardia and Taquicardia
# There is a diference between: q and Q
# There is a diference between: normalmente and Normalmente
# There is a diference between: estive and Estive
# There is a diference between: realmente and Realmente
# There is a diference between: ela and Ela
# There is a diference between: dela and Dela
# There is a diference between: essa and Essa
# There is a diference between: apresentou and Apresentou
# There is a diference between: pelo and Pelo
# There is a diference between: Será and será
# There is a diference between: tenha and Tenha
# There is a diference between: tenha and TENHA
# There is a diference between: fazer and Fazer
# There is a diference between: fazer and FAZER
# There is a diference between: teste and Teste
# There is a diference between: teste and TESTE
# There is a diference between: também and Também
# There is a diference between: aos and Aos
# There is a diference between: tenham and Tenham
# There is a diference between: momento and Momento
# There is a diference between: momento and MOMENTO
# There is a diference between: então and Então
# There is a diference between: melhor and Melhor
# There is a diference between: sintoma and SINTOMA
# There is a diference between: Gostaria and gostaria
# There is a diference between: Gostaria and GOSTARIA
# There is a diference between: qual and Qual
# There is a diference between: qual and QUAL
# There is a diference between: esses and Esses
# There is a diference between: ir and Ir
# There is a diference between: ir and IR
# There is a diference between: Arritmia and arritmia
# There is a diference between: estamos and Estamos
# There is a diference between: espirrando and Espirrando
# There is a diference between: Depois and depois
# There is a diference between: apareceu and Apareceu
# There is a diference between: síndrome and Síndrome
# There is a diference between: ja and Ja
# There is a diference between: fez and Fez
# There is a diference between: Pois and pois
# There is a diference between: mal and Mal
# There is a diference between: estar and Estar
# There is a diference between: Há and há
# There is a diference between: sentiu and Sentiu
# There is a diference between: tomou and Tomou
# There is a diference between: dorflex and Dorflex
# There is a diference between: Dr and dr
# There is a diference between: c and C
# There is a diference between: moleza and Moleza
# There is a diference between: possa and Possa
# There is a diference between: devo and Devo
# There is a diference between: devo and DEVO
# There is a diference between: ao and Ao
# There is a diference between: ao and AO
# There is a diference between: devido and Devido
# There is a diference between: tive and Tive
# There is a diference between: algo and Algo
# There is a diference between: meu and Meu
# There is a diference between: meu and MEU
# There is a diference between: Muitoo and muitoo
# There is a diference between: quarta and Quarta
# There is a diference between: vou and Vou
# There is a diference between: hospital and HOSPITAL
# There is a diference between: hospital and Hospital
# There is a diference between: onde and Onde
# There is a diference between: qualquer and Qualquer
# There is a diference between: coisa and COISA
# There is a diference between: poderia and Poderia
# There is a diference between: N and n
# There is a diference between: seria and Seria
# There is a diference between: sobre and Sobre
# There is a diference between: doença and Doença
# There is a diference between: caso and Caso
# There is a diference between: caso and CASO
# There is a diference between: moro and Moro
# There is a diference between: estão and Estão
# There is a diference between: Obgda and obgda
# There is a diference between: PELA and pela
# There is a diference between: PELA and Pela
# There is a diference between: era and Era
# There is a diference between: era and ERA
# There is a diference between: medicamento and Medicamento
# There is a diference between: Porque and porque
# There is a diference between: irritação and Irritação
# There is a diference between: passa and Passa
# There is a diference between: pq and Pq
# There is a diference between: pânico and Pânico
# There is a diference between: aqui and Aqui
# There is a diference between: aqui and AQUI
# There is a diference between: temos and Temos
# There is a diference between: apenas and Apenas
# There is a diference between: meio and MEIO
# There is a diference between: amanhã and Amanhã
# There is a diference between: procuro and Procuro
# There is a diference between: saúde and Saúde
# There is a diference between: saúde and SAÚDE
# There is a diference between: UPA and upa
# There is a diference between: UPA and Upa
# There is a diference between: cansada and Cansada
# There is a diference between: sentir and Sentir
# There is a diference between: fraqueza and Fraqueza
# There is a diference between: consigo and Consigo
# There is a diference between: ficar and Ficar
# There is a diference between: parece and Parece
# There is a diference between: meus and Meus
# There is a diference between: meus and MEUS
# There is a diference between: desculpe and Desculpe
# There is a diference between: tomo and Tomo
# There is a diference between: tomo and TOMO
# There is a diference between: gosto and Gosto
# There is a diference between: difícil and Difícil
# There is a diference between: qdo and Qdo
# There is a diference between: passo and Passo
# There is a diference between: Graças and graças
# There is a diference between: Obg and obg
# There is a diference between: so and So
# There is a diference between: so and SO
# There is a diference between: agora and Agora
# There is a diference between: tossindo and Tossindo
# There is a diference between: tossindo and TOSSINDO
# There is a diference between: Oq and oq
# There is a diference between: Qndo and qndo
# There is a diference between: começo and Começo
# There is a diference between: nessa and Nessa
# There is a diference between: logo and Logo
# There is a diference between: Cert and cert
# There is a diference between: oi and Oi
# There is a diference between: coriza and Coriza
# There is a diference between: continuo and Continuo
# There is a diference between: posto and Posto
# There is a diference between: funciona and Funciona
# There is a diference between: Faz and faz
# There is a diference between: muita and Muita
# There is a diference between: muita and MUITA
# There is a diference between: muita and MuitA
# There is a diference between: deve and Deve
# There is a diference between: procurar and Procurar
# There is a diference between: Comprei and comprei
# There is a diference between: farmácia and Farmácia
# There is a diference between: começou and Começou
# There is a diference between: respiro and Respiro
# There is a diference between: ardência and Ardência
# There is a diference between: Piora and piora
# There is a diference between: fica and Fica
# There is a diference between: forte and Forte
# There is a diference between: aí and Aí
# There is a diference between: voltar and VOLTAR
# There is a diference between: Quero and quero
# There is a diference between: tbm and Tbm
# There is a diference between: Dói and dói
# There is a diference between: Outra and outra
# There is a diference between: vc and Vc
# There is a diference between: vc and VC
# There is a diference between: problema and PROBLEMA
# There is a diference between: ansiedade and Ansiedade
# There is a diference between: nervoso and Nervoso
# There is a diference between: baixa and Baixa
# There is a diference between: diarréia and Diarréia
# There is a diference between: todo and Todo
# There is a diference between: as and As
# There is a diference between: ivermectina and Ivermectina
# There is a diference between: azitromicina and Azitromicina
# There is a diference between: azitromicina and AZITROMICINA
# There is a diference between: boca and Boca
# There is a diference between: Acabei and acabei
# There is a diference between: aliviou and Aliviou
# There is a diference between: crises and Crises
# There is a diference between: sempre and Sempre
# There is a diference between: Entendi and entendi
# There is a diference between: acha and Acha
# There is a diference between: acha and ACHA
# There is a diference between: incômodo and Incômodo
# There is a diference between: respirar and Respirar
# There is a diference between: teve and Teve
# There is a diference between: continuar and CONTINUAR
# There is a diference between: junto and Junto
# There is a diference between: mim and Mim
# There is a diference between: desconforto and Desconforto
# There is a diference between: tivesse and TIVESSE
# There is a diference between: ate and Ate
# There is a diference between: ótimo and Ótimo
# There is a diference between: alguém and Alguém
# There is a diference between: fora and Fora
# There is a diference between: tinha and Tinha
# There is a diference between: Vieram and vieram
# There is a diference between: Você and você
# There is a diference between: precisa and Precisa
# There is a diference between: precisa and PRECISA
# There is a diference between: Cuido and cuido
# There is a diference between: Ficou and ficou
# There is a diference between: fosse and Fosse
# There is a diference between: fosse and FOSSE
# There is a diference between: Tontura and tontura
# There is a diference between: pré and Pré
# There is a diference between: diabética and Diabética
# There is a diference between: anteriores and Anteriores
# There is a diference between: semana and Semana
# There is a diference between: pressão and Pressão
# There is a diference between: marido and Marido
# There is a diference between: sábado and Sábado
# There is a diference between: Nimesulida and nimesulida
# There is a diference between: somente and Somente
# There is a diference between: diminuiu and Diminuiu
# There is a diference between: Procurei and procurei
# There is a diference between: uns and Uns
# There is a diference between: bastante and BASTANTE
# There is a diference between: bastante and Bastante
# There is a diference between: vocês and Vocês
# There is a diference between: diabetes and Diabetes
# There is a diference between: hipertensão and Hipertensão
# There is a diference between: renal and Renal
# There is a diference between: domingo and Domingo
# There is a diference between: principalmente and Principalmente
# There is a diference between: cheguei and Cheguei
# There is a diference between: daqui and Daqui
# There is a diference between: lá and Lá
# There is a diference between: dizer and DIZER
# There is a diference between: Oseltamivir and oseltamivir
# There is a diference between: estava and Estava
# There is a diference between: continua and Continua
# There is a diference between: esta and Esta
# There is a diference between: esta and ESTA
# There is a diference between: melhorando and Melhorando
# There is a diference between: mto and Mto
# There is a diference between: refluxo and Refluxo
# There is a diference between: esforço and Esforço
# There is a diference between: percebi and Percebi
# There is a diference between: Gracas and gracas
# There is a diference between: Gracas and GRACAS
# There is a diference between: trabalho and Trabalho
# There is a diference between: trabalho and TRABALHO
# There is a diference between: Melhorei and melhorei
# There is a diference between: Fosfato and fosfato
# There is a diference between: dois and DOIS
# There is a diference between: dois and Dois
# There is a diference between: diarreia and Diarreia
# There is a diference between: necessidade and NECESSIDADE
# There is a diference between: Passei and passei
# There is a diference between: primeiros and Primeiros
# There is a diference between: remedio and REMEDIO
# There is a diference between: infelizmente and Infelizmente
# There is a diference between: tratamento and Tratamento
# There is a diference between: beber and Beber
# There is a diference between: seu and Seu
# There is a diference between: quem and Quem
# There is a diference between: conheço and Conheço
# There is a diference between: antiflamatorio and Antiflamatorio
# There is a diference between: Moca and moca
# There is a diference between: todos and Todos
# There is a diference between: nós and Nós
# There is a diference between: fazem and Fazem
# There is a diference between: canseira and Canseira
# There is a diference between: pelos and Pelos
# There is a diference between: bombinha and Bombinha
# There is a diference between: Aerolin and aerolin
# There is a diference between: usei and Usei
# There is a diference between: geralmente and Geralmente
# There is a diference between: plano and PLANO
# There is a diference between: fui and Fui
# There is a diference between: fui and FUI
# There is a diference between: Vick and vick
# There is a diference between: sinais and Sinais
# There is a diference between: asma and Asma
# There is a diference between: Verifiquei and verifiquei
# There is a diference between: Luciana and luciana
# There is a diference between: Dei and dei
# There is a diference between: entre and Entre
# There is a diference between: frebre and Frebre
# There is a diference between: desculpa and Desculpa
# There is a diference between: acontece and Acontece
# There is a diference between: aparentemente and Aparentemente
# There is a diference between: incomoda and Incomoda
# There is a diference between: Ai and ai
# There is a diference between: Ai and AI
# There is a diference between: Coronavirus and coronavirus
# There is a diference between: agradeço and Agradeço
# There is a diference between: Doutora and doutora
# There is a diference between: fraca and Fraca
# There is a diference between: tmb and Tmb
# There is a diference between: tmb and TMB
# There is a diference between: angustiada and Angustiada
# There is a diference between: estômago and Estômago
# There is a diference between: mandou and Mandou
# There is a diference between: Receitou and receitou
# There is a diference between: loratadina and Loratadina
# There is a diference between: rosto and Rosto
# There is a diference between: Pouca and pouca
# There is a diference between: Mente and mente
# There is a diference between: Costa and costa
# There is a diference between: qd and Qd
# There is a diference between: primeiro and Primeiro
# There is a diference between: precisei and Precisei
# There is a diference between: ando and Ando
# There is a diference between: redoxon and Redoxon
# There is a diference between: piorar and PIORAR
# There is a diference between: dos and Dos
# There is a diference between: dos and DOS
# There is a diference between: levar and Levar
# There is a diference between: sente and Sente
# There is a diference between: saude and SAUDE
# There is a diference between: ana and Ana
# There is a diference between: Tipo and tipo
# There is a diference between: Ah and ah
# There is a diference between: outros and Outros
# There is a diference between: rx and RX
# There is a diference between: koid and Koid
# There is a diference between: acabou and Acabou
# There is a diference between: Fadiga and fadiga
# There is a diference between: ñ and Ñ
# There is a diference between: renite and Renite
# There is a diference between: Diante and diante
# There is a diference between: Diante and DIANTE
# There is a diference between: coco and Coco
# There is a diference between: quase and Quase
# There is a diference between: torse and Torse
# There is a diference between: Sao and sao
# There is a diference between: sabe and Sabe
# There is a diference between: Alprazolam and alprazolam
# There is a diference between: consegui and Consegui
# There is a diference between: tv and TV
# There is a diference between: Olá and olá
# There is a diference between: amanheci and Amanheci
# There is a diference between: melhorou and Melhorou
# There is a diference between: preocupa and PREOCUPA
# There is a diference between: suor and Suor
# There is a diference between: suor and SUOR
# There is a diference between: Voltei and voltei
# There is a diference between: perdi and Perdi
# There is a diference between: lhe and LHE
# There is a diference between: acredito and Acredito
# There is a diference between: água and Água
# There is a diference between: daí and Daí
# There is a diference between: escarro and Escarro
# There is a diference between: catarro and CATARRO
# There is a diference between: branca and Branca
# There is a diference between: respirando and Respirando
# There is a diference between: Além and além
# There is a diference between: único and Único
# There is a diference between: Sopro and sopro
# There is a diference between: iniciei and Iniciei
# There is a diference between: melhora and Melhora
# There is a diference between: nesse and Nesse
# There is a diference between: nesse and NESSE
# There is a diference between: entendo and Entendo
# There is a diference between: pcr and PCR
# There is a diference between: indisposição and Indisposição
# There is a diference between: desses and Desses
# There is a diference between: Vomitou and vomitou
# There is a diference between: Sinta and sinta
# There is a diference between: mta and Mta
# There is a diference between: sai and Sai
# There is a diference between: diabetico and DIABETICO
# There is a diference between: hipertenso and HIPERTENSO
# There is a diference between: hipertenso and Hipertenso
# There is a diference between: apesar and Apesar
# There is a diference between: X and x
# There is a diference between: possivelmente and Possivelmente
# There is a diference between: Perguntei and perguntei
# There is a diference between: Comecou and comecou
# There is a diference between: levo and Levo
# There is a diference between: benegripe and Benegripe
# There is a diference between: benegripe and BENEGRIPE
# There is a diference between: às and Às
# There is a diference between: falei and Falei
# There is a diference between: porem and Porem
# There is a diference between: desloratadina and Desloratadina
# There is a diference between: Pensei and pensei
# There is a diference between: Quanto and quanto
# There is a diference between: indicado and Indicado
# There is a diference between: dose and DOSE
# There is a diference between: hipertensa and Hipertensa
# There is a diference between: mal-estar and Mal-estar
# There is a diference between: tento and Tento
# There is a diference between: peguei and Peguei
# There is a diference between: terça and Terça
# There is a diference between: Corre and corre
# There is a diference between: Tivemos and tivemos
# There is a diference between: podemos and Podemos
# There is a diference between: Fomos and fomos
# There is a diference between: falo and Falo
# There is a diference between: Tampa and tampa
# There is a diference between: Incômoda and incômoda
# There is a diference between: Hidroxicloroquina and hidroxicloroquina
# There is a diference between: Oque and oque
# There is a diference between: terminei and Terminei
# There is a diference between: minhas and Minhas
# There is a diference between: vcs and Vcs
# There is a diference between: tb and TB
# There is a diference between: tb and Tb
# There is a diference between: tórax and Tórax
# There is a diference between: acordei and Acordei
# There is a diference between: bebo and Bebo
# There is a diference between: Essas and essas
# There is a diference between: diz and Diz
# There is a diference between: fortaleza and Fortaleza
# There is a diference between: fortaleza and FORTALEZA
# There is a diference between: sendo and Sendo
# There is a diference between: perca and Perca
# There is a diference between: possuo and Possuo
# There is a diference between: covid-19 and Covid-19
# There is a diference between: covid-19 and COVID-19
# There is a diference between: fibromialgia and Fibromialgia
# There is a diference between: diabete and Diabete
# There is a diference between: Querendo and querendo
# There is a diference between: losartana and Losartana
# There is a diference between: algumas and Algumas
# There is a diference between: ultimamente and Ultimamente
# There is a diference between: expectorante and EXPECTORANTE
# There is a diference between: expec and EXPEC
# There is a diference between: Tentei and tentei
# There is a diference between: ardendo and Ardendo
# There is a diference between: aerosol and Aerosol
# There is a diference between: cansado and CANSADO
# There is a diference between: tambem and Tambem
# There is a diference between: perdir and Perdir
# There is a diference between: dormi and Dormi
# There is a diference between: atestado and ATESTADO
# There is a diference between: sério and Sério
# There is a diference between: Irmã and irmã
# There is a diference between: notei and Notei
# There is a diference between: ficando and Ficando
# There is a diference between: intenso and Intenso
# There is a diference between: intenso and INTENSO
# There is a diference between: nesses and Nesses
# There is a diference between: foram and Foram
# There is a diference between: nn and Nn
# There is a diference between: obgd and Obgd
# There is a diference between: hidroclorotiazida and Hidroclorotiazida
# There is a diference between: respiratório and Respiratório
# There is a diference between: existe and Existe
# There is a diference between: teria and Teria
# There is a diference between: Buscopan and buscopan
# There is a diference between: Novalgina and novalgina
# There is a diference between: sol and Sol
# There is a diference between: Hje and hje
# There is a diference between: Moça and moça
# There is a diference between: Li and li
# There is a diference between: após and Após
# There is a diference between: ctz and Ctz
# There is a diference between: falando and Falando
# There is a diference between: senhora and SENHORA
# There is a diference between: sexta and Sexta
# There is a diference between: recentemente and Recentemente
# There is a diference between: floratil and Floratil
# There is a diference between: Varias and varias
# There is a diference between: continuei and Continuei
# There is a diference between: Dependendo and dependendo
# There is a diference between: permaneço and Permaneço
# There is a diference between: canso and Canso
# There is a diference between: espirrei and Espirrei
# There is a diference between: possível and Possível
# There is a diference between: passaram and Passaram
# There is a diference between: Messejana and messejana
# There is a diference between: gripada and Gripada
# There is a diference between: Fabiana and fabiana
# There is a diference between: comprimido and Comprimido
# There is a diference between: bruna and Bruna
# There is a diference between: umas and Umas
# There is a diference between: calafrio and Calafrio
# There is a diference between: vejo and Vejo
# There is a diference between: quer and QUER
# There is a diference between: ótima and Ótima
# There is a diference between: sinceramente and Sinceramente
# There is a diference between: Graça and graça
# There is a diference between: quinta and Quinta
# There is a diference between: achei and Achei
# There is a diference between: achei and ACHEI
# There is a diference between: msm and Msm
# There is a diference between: obrigadaaa and Obrigadaaa
# There is a diference between: lavagem and Lavagem
# There is a diference between: ibuprofeno and Ibuprofeno
# There is a diference between: doi and Doi
# There is a diference between: confusão and Confusão
# There is a diference between: mental and Mental
# There is a diference between: grato and Grato
# There is a diference between: Sra and sra
# There is a diference between: maior and MAIOR
# There is a diference between: Treino and treino
# There is a diference between: olha and Olha
# There is a diference between: fluoxetina and Fluoxetina
# There is a diference between: remedios and REMEDIOS
# There is a diference between: fique and Fique
# There is a diference between: p and P
# There is a diference between: Estávamos and estávamos
# There is a diference between: ms and Ms
# There is a diference between: agr and Agr
# There is a diference between: neste and Neste
# There is a diference between: Entao and entao
# There is a diference between: demos and Demos
# There is a diference between: tilenol and Tilenol
# There is a diference between: Adianta and adianta
# There is a diference between: vacina and Vacina
# There is a diference between: Isolado and isolado
# There is a diference between: tamiflu and Tamiflu
# There is a diference between: vamos and VAMOS
# There is a diference between: bairro and Bairro
# There is a diference between: Aquele and aquele
# There is a diference between: levei and Levei
# There is a diference between: lavei and Lavei
# There is a diference between: Totalmente and totalmente
# There is a diference between: piorou and Piorou
# There is a diference between: Entrei and entrei
# There is a diference between: gente and Gente
# There is a diference between: Demais and demais
# There is a diference between: questão and Questão
# There is a diference between: Nosso and nosso
# There is a diference between: devemos and Devemos
# There is a diference between: mt and MT
# There is a diference between: mt and Mt
# There is a diference between: talvez and Talvez
# There is a diference between: Tatiana and tatiana
# There is a diference between: deixa and Deixa
# There is a diference between: td and TD
# There is a diference between: coloquei and Coloquei
# There is a diference between: ha and Ha
# There is a diference between: acordo and Acordo
# There is a diference between: coristina and Coristina
# There is a diference between: Rinosoro and rinosoro
# There is a diference between: Desorientação and desorientação
# There is a diference between: cloridrato and Cloridrato
# There is a diference between: vim and Vim
# There is a diference between: líquida and Líquida
# There is a diference between: espirro and Espirro
# There is a diference between: pergunto and Pergunto
# There is a diference between: prostração and Prostração
# There is a diference between: alimentação and Alimentação
# There is a diference between: ajudou and Ajudou
# There is a diference between: prednisona and Prednisona
# There is a diference between: multigrip and Multigrip
# There is a diference between: multi and Multi
# There is a diference between: costuma and Costuma
# There is a diference between: Dizem and dizem
# There is a diference between: estes and Estes
# There is a diference between: grata and Grata
# There is a diference between: doenças and Doenças
# There is a diference between: vão and Vão
# There is a diference between: Flex and flex
# There is a diference between: Observo and observo
# There is a diference between: azitomicina and Azitomicina
# There is a diference between: tanto and Tanto
# There is a diference between: UPAs and upas
# There is a diference between: UPAs and Upas
# There is a diference between: UPAs and UPAS
# There is a diference between: desculpas and Desculpas
# There is a diference between: tireoide and Tireoide
# There is a diference between: Parabéns and parabéns
# There is a diference between: quinta-feira and Quinta-feira
# There is a diference between: Transparente and transparente
# There is a diference between: SENHOR and senhor
# There is a diference between: SENHOR and Senhor
# There is a diference between: Agradecido and agradecido
# There is a diference between: referente and Referente
# There is a diference between: fato and FATO
# There is a diference between: tolrest and Tolrest
# There is a diference between: elas and Elas
# There is a diference between: Neosoro and neosoro
# There is a diference between: Coronavírus and coronavírus
# There is a diference between: assintomática and Assintomática
# There is a diference between: espiros and Espiros
# There is a diference between: H1N1 and h1n1
# There is a diference between: morrendo and Morrendo
# There is a diference between: koide and Koide
# There is a diference between: obrigadaa and Obrigadaa
# There is a diference between: tentando and Tentando
# There is a diference between: voce and Voce
# There is a diference between: musculação and Musculação
# There is a diference between: Irei and irei
# There is a diference between: Doutor and doutor
# There is a diference between: Mulher and mulher
# There is a diference between: possui and Possui
# There is a diference between: esteve and Esteve
# There is a diference between: ei and Ei
# There is a diference between: espero and Espero
# There is a diference between: paco and Paco
# There is a diference between: afastado and AFASTADO
# There is a diference between: cansaco and Cansaco
# There is a diference between: TERMINA and termina
# There is a diference between: DEZ and dez
# There is a diference between: SOCIAL and social
# There is a diference between: poq and Poq
# There is a diference between: Kkk and kkk
# There is a diference between: Péssima and péssima
# There is a diference between: Enfim and enfim
# There is a diference between: Sonolência and sonolência
# There is a diference between: peço and Peço
# There is a diference between: começaram and Começaram
# There is a diference between: doloridas and Doloridas
# There is a diference between: cimegripe and Cimegripe
# There is a diference between: Começei and começei
# There is a diference between: rua and Rua
# There is a diference between: contínuo and Contínuo
# There is a diference between: meditação and Meditação
# There is a diference between: sozinha and SOZINHA
# There is a diference between: Nervosismo and nervosismo
# There is a diference between: Esqueci and esqueci
# There is a diference between: sinvastatina and Sinvastatina
# There is a diference between: aas and AAS
# There is a diference between: Sulfametoxazol and sulfametoxazol
# There is a diference between: Canidezinho and canidezinho
# There is a diference between: Falaram and falaram
# There is a diference between: formigamento and Formigamento
# There is a diference between: inclusive and Inclusive
# There is a diference between: Tose and tose
# There is a diference between: foco and Foco
# There is a diference between: estando and Estando
# There is a diference between: Aonde and aonde
# There is a diference between: Fisico and fisico
# There is a diference between: livre and LIVRE
# There is a diference between: pés and Pés
# There is a diference between: Desânimo and desânimo
# There is a diference between: palpitações and Palpitações
# There is a diference between: sus and SUS
# There is a diference between: ESCOLA and escola
# There is a diference between: Preocupante and preocupante
# There is a diference between: Relatei and relatei
# There is a diference between: apresentamos and Apresentamos
# There is a diference between: Continuamos and continuamos
# There is a diference between: h and H
# There is a diference between: Diazepam and diazepam
# There is a diference between: atrapalha and Atrapalha
# There is a diference between: Edson and edson
# There is a diference between: Queiroz and queiroz
# There is a diference between: secrecao and SECRECAO
# There is a diference between: Continuando and continuando
# There is a diference between: paro and Paro
# There is a diference between: más and Más
# There is a diference between: imunoglucan and Imunoglucan
# There is a diference between: serve and Serve
# There is a diference between: Peitoral and peitoral
# There is a diference between: RECOMENDADA and recomendada
# There is a diference between: MEDICA and medica
# There is a diference between: APRESENTAVA and apresentava
# There is a diference between: Prq and prq
# There is a diference between: Achamos and achamos
# There is a diference between: Perturbada and perturbada
# There is a diference between: observei and Observei

# %%
vocab = {}

vocab['unknown'] = np.zeros(len(df.loc[0].word_embeddings[0]))

for index, row in df.iterrows():
  for index, token in enumerate(row['tokens']):
    token_lower = token.lower()
    word_embedding = np.array(row['word_embeddings'][index])
    
    if token_lower not in vocab and np.any(word_embedding):
      vocab[token_lower] = word_embedding 


n_source_words = len(vocab)

print(n_source_words)
# Out:
# 5362

# %%
df['intent'].value_counts()
# Out:
# inform_symptoms    5474
# request_inform     1278
# greeting           1175
# inform_medicine     889
# Name: intent, dtype: int64

# %%
max_len = df['tokens'].apply(lambda x : len(x)).max()
print(max_len)
# max_len = 700 #75% do dataset pelo menos tem no maximo esse valor de tamanho
# Out:
# 103

# %%
def create_embedding_matrix(vocab, n_words, emb_size):
    
    pret_embedding = {}
    embedding_matrix = np.zeros((n_words, emb_size))
    count = 0

    # Dicionário com todos os ids e palavras do embedding pré-treinado
    # for index, word in enumerate(vocab.index_to_key):
    for index, word in enumerate(vocab.keys()):
      pret_embedding[word] = index

    # Construindo a embedding_matrix do embedding pré-treinado
    for item in pret_embedding.items():
      if item[1] < n_words:
        count += 1
        embedding_vector = vocab[item[0]]
        if embedding_vector is not None:
          embedding_matrix[item[1]] = embedding_vector
      
    return embedding_matrix

# %% [markdown]
# ## Save the vectors  in a new Matrix

# %%
# embedding_size = 300
embedding_size = len(df.loc[0].word_embeddings[0])
embedding_matrix = create_embedding_matrix(vocab, n_source_words, embedding_size)
embedding_matrix.shape
# Out:
# (5362, 768)

# %%
vocab_key_2_index =  {key: index for index, key in enumerate(vocab.keys())}

# %% [markdown]
# ## Padding

# %%
# Função que cria o X
def create_x(tokens):
    list_x = []
    for token in tokens:
      if(token in vocab_key_2_index):
        list_x.append(vocab_key_2_index[token])
      
    return list_x

# %%
df['token_indexes'] = df['tokens'].apply(lambda tokens : create_x(tokens))
df.head(5)
# Out:
#                                                  txt  \
# 0            Tô  muito nervosa Marcela com tudo isso
# 1                                     Com muito medo
# 2                                                Não
# 3  Tem algum remédio  que a pessoa tome para se a...
# 4                                          Tá  certo
#
#                                        annotated_txt           intent  \
# 0            Tô  muito nervosa Marcela com tudo isso  inform_symptoms
# 1                                     Com muito medo  inform_symptoms
# 2                                                Não         greeting
# 3  Tem algum remédio  que a pessoa tome para se a...   request_inform
# 4                                          Tá  certo         greeting
#
#                                           embeddings  \
# 0  [[-0.17518604000000002, -0.38116214, 0.1568575...
# 1  [[0.40117407, -0.22014676, 0.1467775, 0.185312...
# 2  [[0.0857483, -0.41115219999999997, 0.28060192,...
# 3  [[-0.018409189, -0.17020282, 0.273364780000000...
# 4  [[0.2476745, -0.31360537, 0.040109605, 0.37392...
#
#                                               tokens  \
# 0     [Tô, muito, nervosa, Marcela, com, tudo, isso]
# 1                                 [Com, muito, medo]
# 2                                              [Não]
# 3  [Tem, algum, remédio, que, a, pessoa, tome, pa...
# 4                                        [Tá, certo]
#
#                                      word_embeddings  \
# 0  [[0.10563439000000001, -0.6496529600000001, 0....
# 1  [[0.5744509, -0.58911455, 0.11015732600000001,...
# 2  [[0.0857483, -0.41115219999999997, 0.28060192,...
# 3  [[-0.026540479000000002, -0.44967073, 0.199957...
# 4  [[0.29746079999999997, -0.3857502, 0.25457925,...
#
#                           token_indexes
# 0                       [2, 3, 5, 6, 7]
# 1                                [2, 8]
# 2                                    []
# 3  [11, 12, 13, 14, 15, 16, 17, 18, 19]
# 4                                  [21]

# %%
X = pad_sequences(maxlen=max_len, sequences=df['token_indexes'], value=0, padding='post', truncating='post')
Y = pd.get_dummies(df['intent']).values
(X.shape, Y.shape)
# Out:
# ((8816, 103), (8816, 4))

# %% [markdown]
# ## Create train and test

# %%
X_train, X_test, Y_train, Y_test = train_test_split(X,Y, test_size = 0.20, random_state = 42,stratify=Y)
print(X_train.shape,Y_train.shape)
print(X_test.shape,Y_test.shape)
# Out:
# (7052, 103) (7052, 4)
# (1764, 103) (1764, 4)

# %% [markdown]
# ## LSTM Model

# %%
num_labels = Y.shape[1]
MAX_NB_WORDS = n_source_words
# EMBEDDING_DIM = 50
EMBEDDING_DIM = embedding_size

model = Sequential()
model.add(Embedding(MAX_NB_WORDS, EMBEDDING_DIM, input_length=X.shape[1], weights=[embedding_matrix]))
# model.add(Embedding(X.shape[0], X.shape[1], input_length=X.shape[1], weights=[X]))
model.add(Bidirectional(LSTM(64)))
model.add(Dropout(0.1))
model.add(Dense(num_labels, activation='softmax'))
model.compile(loss='categorical_crossentropy', optimizer='adam', metrics=['accuracy'])
#Optimisation functions usually calculate the gradient i.e. the partial derivative of loss function with respect to weights, 
#and the weights are modified in the opposite direction of the calculated gradient.
# Out:
# 2022-06-23 16:39:22.860433: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:936] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-06-23 16:39:22.861824: W tensorflow/stream_executor/platform/default/dso_loader.cc:64] Could not load dynamic library 'libcudart.so.11.0'; dlerror: libcudart.so.11.0: cannot open shared object file: No such file or directory
# 2022-06-23 16:39:22.862005: W tensorflow/stream_executor/platform/default/dso_loader.cc:64] Could not load dynamic library 'libcublas.so.11'; dlerror: libcublas.so.11: cannot open shared object file: No such file or directory
# 2022-06-23 16:39:22.862121: W tensorflow/stream_executor/platform/default/dso_loader.cc:64] Could not load dynamic library 'libcublasLt.so.11'; dlerror: libcublasLt.so.11: cannot open shared object file: No such file or directory
# 2022-06-23 16:39:22.862327: W tensorflow/stream_executor/platform/default/dso_loader.cc:64] Could not load dynamic library 'libcufft.so.10'; dlerror: libcufft.so.10: cannot open shared object file: No such file or directory
# 2022-06-23 16:39:22.862515: W tensorflow/stream_executor/platform/default/dso_loader.cc:64] Could not load dynamic library 'libcurand.so.10'; dlerror: libcurand.so.10: cannot open shared object file: No such file or directory
# 2022-06-23 16:39:22.862547: W tensorflow/stream_executor/platform/default/dso_loader.cc:64] Could not load dynamic library 'libcusolver.so.11'; dlerror: libcusolver.so.11: cannot open shared object file: No such file or directory
# 2022-06-23 16:39:22.862575: W tensorflow/stream_executor/platform/default/dso_loader.cc:64] Could not load dynamic library 'libcusparse.so.11'; dlerror: libcusparse.so.11: cannot open shared object file: No such file or directory
# 2022-06-23 16:39:22.862734: W tensorflow/stream_executor/platform/default/dso_loader.cc:64] Could not load dynamic library 'libcudnn.so.8'; dlerror: libcudnn.so.8: cannot open shared object file: No such file or directory
# 2022-06-23 16:39:22.862741: W tensorflow/core/common_runtime/gpu/gpu_device.cc:1850] Cannot dlopen some GPU libraries. Please make sure the missing libraries mentioned above are installed properly if you would like to use GPU. Follow the guide at https://www.tensorflow.org/install/gpu for how to download and setup the required libraries for your platform.
# Skipping registering GPU devices...
# 2022-06-23 16:39:22.863502: I tensorflow/core/platform/cpu_feature_guard.cc:151] This TensorFlow binary is optimized with oneAPI Deep Neural Network Library (oneDNN) to use the following CPU instructions in performance-critical operations:  AVX2 AVX512F FMA
# To enable them in other operations, rebuild TensorFlow with the appropriate compiler flags.

# %%
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  embedding (Embedding)       (None, 103, 768)          4118016
#
#  bidirectional (Bidirectiona  (None, 128)              426496
#  l)
#
#  dropout (Dropout)           (None, 128)               0
#
#  dense (Dense)               (None, 4)                 516
#
# =================================================================
# Total params: 4,545,028
# Trainable params: 4,545,028
# Non-trainable params: 0
# _________________________________________________________________

# %%
path_model = fm.filename_from_data_dir(f'output/patient/lstm_models/bert_pt.h5')
#model.load_weights(path_model)

# %%
epochs = 20
batch_size = 64

history = model.fit(X_train, Y_train, epochs=epochs, batch_size=batch_size,validation_split=0.1, 
                    callbacks=[EarlyStopping(monitor='val_loss', patience=3, min_delta=0.0001)])
# Out:
# Epoch 1/20
# 100/100 [==============================] - 16s 146ms/step - loss: 0.5078 - accuracy: 0.8046 - val_loss: 0.3136 - val_accuracy: 0.8711
# Epoch 2/20
# 100/100 [==============================] - 14s 138ms/step - loss: 0.2479 - accuracy: 0.8993 - val_loss: 0.2640 - val_accuracy: 0.8952
# Epoch 3/20
# 100/100 [==============================] - 14s 140ms/step - loss: 0.1800 - accuracy: 0.9335 - val_loss: 0.2813 - val_accuracy: 0.8824
# Epoch 4/20
# 100/100 [==============================] - 14s 142ms/step - loss: 0.1387 - accuracy: 0.9488 - val_loss: 0.2975 - val_accuracy: 0.9051
# Epoch 5/20
# 100/100 [==============================] - 14s 142ms/step - loss: 0.1158 - accuracy: 0.9575 - val_loss: 0.3002 - val_accuracy: 0.8952

# %%
working_dir = fm.filename_from_data_dir(f'output/lstm_models/patient/bert_pt')

# %%
print('saving the model')
model.save(f'{working_dir}/model.h5')
# Out:
# saving the model

# %%
print('saving the vocabullary')

file = open(f'{working_dir}/vocabullary.json',"w")

file.write(json.dumps(vocab_key_2_index))

file.close()
# Out:
# saving the vocabullary

# %%
print('saving the metadata')

file = open(f'{working_dir}/metadata.json',"w")

intents = pd.get_dummies(df['intent']).columns.tolist()

metadata = {
  'intents': intents,
  'vector_length': str(max_len)
}

file.write(json.dumps(metadata))

file.close()
# Out:
# saving the metadata

# %% [markdown]
# ## Evaluate the model

# %%
accr = model.evaluate(X_test,Y_test)
print('Test set\n  Loss: {:0.3f}\n  Accuracy: {:0.3f}'.format(accr[0],accr[1]))
# Out:
# 56/56 [==============================] - 1s 19ms/step - loss: 0.2654 - accuracy: 0.8997
# Test set
#   Loss: 0.265
#   Accuracy: 0.900
