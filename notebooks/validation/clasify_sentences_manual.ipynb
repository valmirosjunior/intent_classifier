# %%
import pandas as pd

from src.core import file_manager as fm

# %%
df = pd.read_csv(fm.filename_from_data_dir('output/patient/clean_sentences.csv'))


sentences_to_add_manual_label = df.sample(n=1000, random_state=42)['txt']

output_file = fm.filename_from_data_dir('output/patient/sentences_to_add_label_manual.csv')

sentences_to_add_manual_label.to_csv(output_file, index=False)

sentences_to_add_manual_label.head()
# Out:
#                         _id                       cri  \
# 8285   Jo43Chkm3NgWSh29X-26  2020-05-06T02:33:00.680Z
# 5090   NgKjXyYZWNsLg3cfg-33  2020-05-05T21:42:39.705Z
# 9816   hKZ4YGatnDnMqShr4-18  2020-05-04T01:33:34.920Z
# 23101   C3cigm8pSTLmMxX5n-2  2020-05-01T01:20:18.552Z
# 11817  K343xkpaSNWutHKLe-16  2020-05-03T23:33:13.606Z
#
#                             atu                idp      ori  \
# 8285   2020-05-06T03:59:41:267Z  KPjqcRMYjPBGJuqpw  patient
# 5090   2020-05-06T00:25:31:628Z  C93WScSZitLQxNQcT  patient
# 9816   2020-05-04T01:40:44:990Z  NwGGNu46L2donEJQZ  patient
# 23101  2020-05-01T01:51:10:383Z  sk29s4dWpdxQMAMod  patient
# 11817  2020-05-03T23:52:24:312Z  SqPeKkaNDEbKZiP8Q  patient
#
#                                                      txt      created_at  \
# 8285                                            Quase 39  20-05-06T02:33
# 5090   Meu nariz tá entupido né mas não tá me incomod...  20-05-05T21:42
# 9816        Vou avisar ao meu filho da upa granha Lisboa  20-05-04T01:33
# 23101  Boa noite, Valéria. Desde sexta que estou com ...  20-05-01T01:20
# 11817                            estava espirrando muito  20-05-03T23:33
#
#                       id  seq  \
# 8285   Jo43Chkm3NgWSh29X   26
# 5090   NgKjXyYZWNsLg3cfg   33
# 9816   hKZ4YGatnDnMqShr4   18
# 23101  C3cigm8pSTLmMxX5n    2
# 11817  K343xkpaSNWutHKLe   16
#
#                                             original_txt
# 8285                                            Quase 39
# 5090   Meu nariz tá entupido né mas não tá me incomod...
# 9816        Vou avisar ao meu filho da upa granha Lisboa
# 23101  Boa noite, Valéria. Desde sexta que estou com ...
# 11817                            estava espirrando muito

# %%
pd.read_csv(fm.filename_from_data_dir('output/patient/clean_sentences.csv'))
# Out:
#                         _id                       cri  \
# 0       7Nmt894SbdLamfwAo-1  2020-05-04T21:15:55.119Z
# 1       7Nmt894SbdLamfwAo-2  2020-05-04T21:16:21.726Z
# 2       7Nmt894SbdLamfwAo-3  2020-05-04T21:16:49.298Z
# 3       7Nmt894SbdLamfwAo-5  2020-05-04T21:17:23.211Z
# 4       7Nmt894SbdLamfwAo-6  2020-05-04T21:17:43.786Z
# ...                     ...                       ...
# 26749  Q9eztCPd6c3n8Pqvo-10  2020-05-05T12:10:02.461Z
# 26750  Q9eztCPd6c3n8Pqvo-16  2020-05-05T12:12:45.348Z
# 26751  Q9eztCPd6c3n8Pqvo-20  2020-05-05T12:14:06.754Z
# 26752  Q9eztCPd6c3n8Pqvo-21  2020-05-05T12:14:17.802Z
# 26753  Q9eztCPd6c3n8Pqvo-27  2020-05-05T12:15:07.564Z
#
#                             atu                idp      ori  \
# 0      2020-05-04T21:53:06:605Z  2CNgApLrPbw5bsyxG  patient
# 1      2020-05-04T21:53:06:605Z  2CNgApLrPbw5bsyxG  patient
# 2      2020-05-04T21:53:06:605Z  2CNgApLrPbw5bsyxG  patient
# 3      2020-05-04T21:53:06:605Z  2CNgApLrPbw5bsyxG  patient
# 4      2020-05-04T21:53:06:605Z  2CNgApLrPbw5bsyxG  patient
# ...                         ...                ...      ...
# 26749  2020-05-05T12:15:50:697Z  zzb53cgwqLBSWA2Kg  patient
# 26750  2020-05-05T12:15:50:697Z  zzb53cgwqLBSWA2Kg  patient
# 26751  2020-05-05T12:15:50:697Z  zzb53cgwqLBSWA2Kg  patient
# 26752  2020-05-05T12:15:50:697Z  zzb53cgwqLBSWA2Kg  patient
# 26753  2020-05-05T12:15:50:697Z  zzb53cgwqLBSWA2Kg  patient
#
#                                                      txt      created_at  \
# 0                Tô  muito nervosa Marcela com tudo isso  20-05-04T21:15
# 1      O meu problema  é  psicológico    nem dormi es...  20-05-04T21:16
# 2                                         Com muito medo  20-05-04T21:16
# 3                                                    Sim  20-05-04T21:17
# 4           A 3 meses atrás  quando o meu esposo faleceu  20-05-04T21:17
# ...                                                  ...             ...
# 26749                                Ñ, só pressão baixa  20-05-05T12:10
# 26750                                           Atende ?  20-05-05T12:12
# 26751                                Vou ter q ir na Upa  20-05-05T12:14
# 26752                      Por que trabalho em mercantil  20-05-05T12:14
# 26753                            É na varjota q trabalho  20-05-05T12:15
#
#                       id  seq  \
# 0      7Nmt894SbdLamfwAo    1
# 1      7Nmt894SbdLamfwAo    2
# 2      7Nmt894SbdLamfwAo    3
# 3      7Nmt894SbdLamfwAo    5
# 4      7Nmt894SbdLamfwAo    6
# ...                  ...  ...
# 26749  Q9eztCPd6c3n8Pqvo   10
# 26750  Q9eztCPd6c3n8Pqvo   16
# 26751  Q9eztCPd6c3n8Pqvo   20
# 26752  Q9eztCPd6c3n8Pqvo   21
# 26753  Q9eztCPd6c3n8Pqvo   27
#
#                                             original_txt
# 0                Tô  muito nervosa Marcela com tudo isso
# 1      O meu problema  é  psicológico    nem dormi es...
# 2                                         Com muito medo
# 3                                                    Sim
# 4           A 3 meses atrás  quando o meu esposo faleceu
# ...                                                  ...
# 26749                                Ñ, só pressão baixa
# 26750                                           Atende ?
# 26751                                Vou ter q ir na Upa
# 26752                      Por que trabalho em mercantil
# 26753                            É na varjota q trabalho
#
# [26754 rows x 10 columns]
