# %%
# %load_ext autoreload

# %autoreload 2

# %%
from src.metrics_helper import MetricHelper

# %%
metrics_helper = MetricHelper('patient')

# %%
metrics_helper.show_davies_bouldin_score()

# %%
metrics_helper.show_silhouette_score()
